# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")
df = df.drop(columns=['id'])

# %%
# output and input to model
df = df[df[" Bare_Nuclei"] != '?'].astype('int64')
in_ = df.drop(columns=[' Class']) - 1
in_ = in_/9
out_ = df.iloc[:, -1] // 2 - 1

# %%
df_1 = pd.concat([in_, out_], axis=1)
df_1.to_csv('adjusted.csv')

# %%
for column in in_.columns:
    plt.title(column)
    plt.scatter([i for i in range(len(in_[column]))], in_[column], c=out_, s=10)
    plt.show()
    
# purple = Benign, yellow = Malignant

# %%
"""# in conparison to Clump_Thickness

for column in in_.columns:
    if column == ' Clump_Thickness':
        continue
    plt.title("Clump_Thickness vs" + column)
    plt.scatter(in_[" Clump_Thickness"], in_[column], c=out_, s=10)
    plt.show()"""
# Out:
# '# in conparison to Clump_Thickness\n\nfor column in in_.columns:\n    if column == \' Clump_Thickness\':\n        continue\n    plt.title("Clump_Thickness vs" + column)\n    plt.scatter(in_[" Clump_Thickness"], in_[column], c=out_, s=10)\n    plt.show()'
